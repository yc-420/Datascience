# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Data understanding
#Check data type
ABC= pd.read_csv('garments_worker_productivity.csv')

ABC
# Out:
#            date   quarter  department        day  team  targeted_productivity  \
# 0      1/1/2015  Quarter1      sweing   Thursday     8                   0.80
# 1      1/1/2015  Quarter1  finishing    Thursday     1                   0.75
# 2      1/1/2015  Quarter1      sweing   Thursday    11                   0.80
# 3      1/1/2015  Quarter1      sweing   Thursday    12                   0.80
# 4      1/1/2015  Quarter1      sweing   Thursday     6                   0.80
# ...         ...       ...         ...        ...   ...                    ...
# 1192  3/11/2015  Quarter2   finishing  Wednesday    10                   0.75
# 1193  3/11/2015  Quarter2   finishing  Wednesday     8                   0.70
# 1194  3/11/2015  Quarter2   finishing  Wednesday     7                   0.65
# 1195  3/11/2015  Quarter2   finishing  Wednesday     9                   0.75
# 1196  3/11/2015  Quarter2   finishing  Wednesday     6                   0.70
#
#         smv     wip  over_time  incentive  idle_time  idle_men  \
# 0     26.16  1108.0       7080         98        0.0         0
# 1      3.94     NaN        960          0        0.0         0
# 2     11.41   968.0       3660         50        0.0         0
# 3     11.41   968.0       3660         50        0.0         0
# 4     25.90  1170.0       1920         50        0.0         0
# ...     ...     ...        ...        ...        ...       ...
# 1192   2.90     NaN        960          0        0.0         0
# 1193   3.90     NaN        960          0        0.0         0
# 1194   3.90     NaN        960          0        0.0         0
# 1195   2.90     NaN       1800          0        0.0         0
# 1196   2.90     NaN        720          0        0.0         0
#
#       no_of_style_change  no_of_workers  actual_productivity
# 0                      0           59.0             0.940725
# 1                      0            8.0             0.886500
# 2                      0           30.5             0.800570
# 3                      0           30.5             0.800570
# 4                      0           56.0             0.800382
# ...                  ...            ...                  ...
# 1192                   0            8.0             0.628333
# 1193                   0            8.0             0.625625
# 1194                   0            8.0             0.625625
# 1195                   0           15.0             0.505889
# 1196                   0            6.0             0.394722
#
# [1197 rows x 15 columns]

# %%
print("Info:") # data types and non-null 
ABC.info()
('\n')
print("Shape:", ABC.shape) #dimension
# Out:
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   1197 non-null   object
#  1   quarter                1197 non-null   object
#  2   department             1197 non-null   object
#  3   day                    1197 non-null   object
#  4   team                   1197 non-null   int64
#  5   targeted_productivity  1197 non-null   float64
#  6   smv                    1197 non-null   float64
#  7   wip                    691 non-null    float64
#  8   over_time              1197 non-null   int64
#  9   incentive              1197 non-null   int64
#  10  idle_time              1197 non-null   float64
#  11  idle_men               1197 non-null   int64
#  12  no_of_style_change     1197 non-null   int64
#  13  no_of_workers          1197 non-null   float64
#  14  actual_productivity    1197 non-null   float64
# dtypes: float64(6), int64(5), object(4)
# memory usage: 140.4+ KB
# Shape: (1197, 15)

# %%
ABC.describe()
# Out:
#               team  targeted_productivity          smv           wip  \
# count  1197.000000            1197.000000  1197.000000    691.000000
# mean      6.426901               0.729632    15.062172   1190.465991
# std       3.463963               0.097891    10.943219   1837.455001
# min       1.000000               0.070000     2.900000      7.000000
# 25%       3.000000               0.700000     3.940000    774.500000
# 50%       6.000000               0.750000    15.260000   1039.000000
# 75%       9.000000               0.800000    24.260000   1252.500000
# max      12.000000               0.800000    54.560000  23122.000000
#
#           over_time    incentive    idle_time     idle_men  \
# count   1197.000000  1197.000000  1197.000000  1197.000000
# mean    4567.460317    38.210526     0.730159     0.369256
# std     3348.823563   160.182643    12.709757     3.268987
# min        0.000000     0.000000     0.000000     0.000000
# 25%     1440.000000     0.000000     0.000000     0.000000
# 50%     3960.000000     0.000000     0.000000     0.000000
# 75%     6960.000000    50.000000     0.000000     0.000000
# max    25920.000000  3600.000000   300.000000    45.000000
#
#        no_of_style_change  no_of_workers  actual_productivity
# count         1197.000000    1197.000000          1197.000000
# mean             0.150376      34.609858             0.735091
# std              0.427848      22.197687             0.174488
# min              0.000000       2.000000             0.233705
# 25%              0.000000       9.000000             0.650307
# 50%              0.000000      34.000000             0.773333
# 75%              0.000000      57.000000             0.850253
# max              2.000000      89.000000             1.120437

# %%
print("Missing Values:")
print(ABC.isnull().sum()) #find missing value
# Out:
# Missing Values:
# date                       0
# quarter                    0
# department                 0
# day                        0
# team                       0
# targeted_productivity      0
# smv                        0
# wip                      506
# over_time                  0
# incentive                  0
# idle_time                  0
# idle_men                   0
# no_of_style_change         0
# no_of_workers              0
# actual_productivity        0
# dtype: int64

# %%
print("\nStatistics summary:")
ABC.describe()
# Out:
# Statistics summary:
#               team  targeted_productivity          smv           wip  \
# count  1197.000000            1197.000000  1197.000000    691.000000
# mean      6.426901               0.729632    15.062172   1190.465991
# std       3.463963               0.097891    10.943219   1837.455001
# min       1.000000               0.070000     2.900000      7.000000
# 25%       3.000000               0.700000     3.940000    774.500000
# 50%       6.000000               0.750000    15.260000   1039.000000
# 75%       9.000000               0.800000    24.260000   1252.500000
# max      12.000000               0.800000    54.560000  23122.000000
#
#           over_time    incentive    idle_time     idle_men  \
# count   1197.000000  1197.000000  1197.000000  1197.000000
# mean    4567.460317    38.210526     0.730159     0.369256
# std     3348.823563   160.182643    12.709757     3.268987
# min        0.000000     0.000000     0.000000     0.000000
# 25%     1440.000000     0.000000     0.000000     0.000000
# 50%     3960.000000     0.000000     0.000000     0.000000
# 75%     6960.000000    50.000000     0.000000     0.000000
# max    25920.000000  3600.000000   300.000000    45.000000
#
#        no_of_style_change  no_of_workers  actual_productivity
# count         1197.000000    1197.000000          1197.000000
# mean             0.150376      34.609858             0.735091
# std              0.427848      22.197687             0.174488
# min              0.000000       2.000000             0.233705
# 25%              0.000000       9.000000             0.650307
# 50%              0.000000      34.000000             0.773333
# 75%              0.000000      57.000000             0.850253
# max              2.000000      89.000000             1.120437

# %%
#Data preparation
ABC['wip'] = ABC['wip'].fillna(0)
print(ABC['wip'].isnull().sum()) #check
# Out:
# 0

# %%
print (ABC['wip'])
# Out:
# 0       1108.0
# 1          0.0
# 2        968.0
# 3        968.0
# 4       1170.0
#          ...
# 1192       0.0
# 1193       0.0
# 1194       0.0
# 1195       0.0
# 1196       0.0
# Name: wip, Length: 1197, dtype: float64

# %%
print(ABC['department'].value_counts()) #check
# Out:
# department
# sweing        691
# finishing     257
# finishing     249
# Name: count, dtype: int64

# %%
#correct sweing -> sewing
ABC['department'] = ABC['department'].replace({'sweing':'sewing'})
print(ABC['department'])
# Out:
# 0           sewing
# 1       finishing
# 2           sewing
# 3           sewing
# 4           sewing
#            ...
# 1192     finishing
# 1193     finishing
# 1194     finishing
# 1195     finishing
# 1196     finishing
# Name: department, Length: 1197, dtype: object

# %%
ABC['date'] = pd.to_datetime(ABC['date']) #datetime variable

print(ABC.dtypes)
# Out:
# date                     datetime64[ns]
# quarter                          object
# department                       object
# day                              object
# team                              int64
# targeted_productivity           float64
# smv                             float64
# wip                             float64
# over_time                         int64
# incentive                         int64
# idle_time                       float64
# idle_men                          int64
# no_of_style_change                int64
# no_of_workers                   float64
# actual_productivity             float64
# dtype: object

# %%
ABC['actual_productivity'].describe()
# Out:
# count    1197.000000
# mean        0.735091
# std         0.174488
# min         0.233705
# 25%         0.650307
# 50%         0.773333
# 75%         0.850253
# max         1.120437
# Name: actual_productivity, dtype: float64

# %%
def outliers_iqr(ys): #using +-1.5x IQR method for defining outliers

    quartile_1, quartile_3 = np.percentile(ys, [25, 75])
    iqr = quartile_3 - quartile_1
    lower_bound = quartile_1 - (iqr * 1.5)
    upper_bound = quartile_3 + (iqr * 1.5)
    return np.where((ys > upper_bound) | (ys < lower_bound))

pos = outliers_iqr(ABC.actual_productivity)
pos
# Out:
# (array([  60,  125,  146,  147,  169,  215,  237,  255,  256,  257,  258,
#          298,  317,  336,  392,  414,  415,  436,  455,  496,  497,  541,
#          560,  577,  578,  579,  689,  690,  691,  748,  765,  783,  784,
#          801,  802,  822,  840,  841,  842,  843,  863,  882,  883,  920,
#          921,  963,  984, 1024, 1045, 1046, 1067, 1086, 1127, 1149]),)

# %%
ABC.iloc[pos[0]]
# Out:
#            date   quarter  department        day  team  targeted_productivity  \
# 60   2015-01-04  Quarter1  finishing      Sunday    11                   0.75
# 125  2015-01-07  Quarter1  finishing   Wednesday     5                   0.70
# 146  2015-01-08  Quarter2      sewing   Thursday    11                   0.35
# 147  2015-01-08  Quarter2      sewing   Thursday     5                   0.70
# 169  2015-01-10  Quarter2  finishing    Saturday     5                   0.50
# 215  2015-01-12  Quarter2  finishing      Monday    10                   0.80
# 237  2015-01-13  Quarter2      sewing    Tuesday    10                   0.35
# 255  2015-01-14  Quarter2      sewing  Wednesday    11                   0.35
# 256  2015-01-14  Quarter2  finishing   Wednesday    10                   0.80
# 257  2015-01-14  Quarter2      sewing  Wednesday     2                   0.80
# 258  2015-01-14  Quarter2  finishing   Wednesday     2                   0.80
# 298  2015-01-17  Quarter3  finishing    Saturday    11                   0.80
# 317  2015-01-18  Quarter3  finishing      Sunday    10                   0.70
# 336  2015-01-19  Quarter3      sewing     Monday    12                   0.35
# 392  2015-01-22  Quarter4  finishing    Thursday    12                   0.60
# 414  2015-01-24  Quarter4      sewing   Saturday     8                   0.35
# 415  2015-01-24  Quarter4  finishing    Saturday     9                   0.60
# 436  2015-01-25  Quarter4  finishing      Sunday     8                   0.80
# 455  2015-01-26  Quarter4      sewing     Monday    11                   0.35
# 496  2015-01-28  Quarter4      sewing  Wednesday     7                   0.60
# 497  2015-01-28  Quarter4  finishing   Wednesday    11                   0.50
# 541  2015-01-31  Quarter5      sewing   Saturday     8                   0.50
# 560  2015-02-01  Quarter1  finishing      Sunday     6                   0.60
# 577  2015-02-02  Quarter1      sewing     Monday     7                   0.70
# 578  2015-02-02  Quarter1  finishing      Monday     6                   0.60
# 579  2015-02-02  Quarter1      sewing     Monday     8                   0.65
# 689  2015-02-09  Quarter2      sewing     Monday     7                   0.35
# 690  2015-02-09  Quarter2      sewing     Monday     8                   0.35
# 691  2015-02-09  Quarter2   finishing     Monday    12                   0.80
# 748  2015-02-12  Quarter2      sewing   Thursday     3                   0.35
# 765  2015-02-14  Quarter2   finishing   Saturday     9                   0.80
# 783  2015-02-15  Quarter3   finishing     Sunday     4                   0.75
# 784  2015-02-15  Quarter3      sewing     Sunday     9                   0.50
# 801  2015-02-16  Quarter3      sewing     Monday     9                   0.60
# 802  2015-02-16  Quarter3   finishing     Monday     7                   0.70
# 822  2015-02-17  Quarter3      sewing    Tuesday    10                   0.65
# 840  2015-02-18  Quarter3      sewing  Wednesday     2                   0.60
# 841  2015-02-18  Quarter3      sewing  Wednesday    10                   0.70
# 842  2015-02-18  Quarter3   finishing  Wednesday     3                   0.50
# 963    2.90     0.0       3360          0        0.0         0
# 984    2.90     0.0       3360          0        0.0         0
# 1024   4.60     0.0       3360          0        0.0         0
# 1045   2.90     0.0       3360          0        0.0         0
# 1046  15.28   157.0       5400          0        6.5        30
# 1067  18.79    52.0       3960          0        0.0         0
# 1086  22.53  1450.0       2640          0        0.0         0
# 1127   2.90     0.0        960          0        0.0         0
# 1149   3.90     0.0          0        960        0.0         0
#
#       no_of_style_change  no_of_workers  actual_productivity
# 60                     0            8.0             0.345833
# 125                    0            8.0             0.330114
# 146                    0           54.0             0.349951
# 147                    0           57.0             0.233705
# 169                    0            8.0             0.337973
# 215                    0            8.0             0.246250
# 237                    0           56.5             0.350206
# 255                    0           55.0             0.350031
# 256                    0            8.0             0.332359
# 257                    0           57.0             0.311207
# 258                    0            8.0             0.247316
# 298                    0            7.0             0.313853
# 317                    0            8.0             0.235795
# 336                    0           34.0             0.350218
# 392                    0            9.0             0.327407
# 414                    0           52.0             0.349990
# 415                    0            8.0             0.261174
# 436                    0            4.0             0.329545
# 455                    0           57.0             0.350067
# 496                    0           55.0             0.285333
# 497                    0            8.0             0.259375
# 541                    0           54.0             0.286985
# 560                    0           10.0             0.314167
# 577                    0           56.0             0.295308
# 578                    0           10.0             0.280333
# 579                    0           55.0             0.260979
# 689                    1           58.0             0.350302
# 690                    1           58.0             0.350302
# 691                    0            9.0             0.272000
# 748                    1           58.0             0.350302
# 765                    0            8.0             0.238042
# 783                    0           20.0             0.287042
# 784                    1           54.0             0.283054
# 801                    1           54.0             0.329965
# 802                    0           15.0             0.258000
# 822                    1           49.0             0.302117
# 840                    1           57.0             0.328132
# 841                    1           47.0             0.303574
# 842                    0            8.0             0.256500
# 843                    2           57.0             0.251399
# 863                    1           48.0             0.249417
# 882                    0           60.0             0.307501
# 883                    0            8.0             0.283958
# 920                    0            8.0             0.325000
# 921                    1           42.0             0.268214
# 963                    0            8.0             0.271875
# 984                    0            8.0             0.271875
# 1024                   0            8.0             0.342361
# 1045                   0            8.0             0.309333
# 1046                   1           45.0             0.302770
# 1067                   0           33.0             0.332146
# 1086                   1           39.0             0.263694
# 1127                   0            8.0             0.271875
# 1149                   0            8.0             0.264062

# %%
sns.boxplot(x=ABC['actual_productivity']) #box-and-whisker plot 
plt.show()

# %%
ABC[ABC['actual_productivity'] > 1] #find overproductivity
# Out:
#           date   quarter  department        day  team  targeted_productivity  \
# 337 2015-01-20  Quarter3  finishing     Tuesday     5                   0.70
# 437 2015-01-26  Quarter4  finishing      Monday     3                   0.75
# 456 2015-01-27  Quarter4      sewing    Tuesday     2                   0.75
# 457 2015-01-27  Quarter4      sewing    Tuesday     3                   0.75
# 477 2015-01-28  Quarter4      sewing  Wednesday     2                   0.80
# 478 2015-01-28  Quarter4      sewing  Wednesday     3                   0.80
# 498 2015-01-29  Quarter5      sewing   Thursday     2                   0.80
# 518 2015-01-31  Quarter5      sewing   Saturday     3                   0.80
# 519 2015-01-31  Quarter5      sewing   Saturday     2                   0.80
# 542 2015-02-01  Quarter1  finishing      Sunday     8                   0.65
# 543 2015-02-01  Quarter1      sewing     Sunday     2                   0.80
# 730  22.52   1397.0          0        138        0.0         0
# 731   4.15      0.0       1800          0        0.0         0
# 732  22.52   1327.0          0        113        0.0         0
# 749  22.52   1416.0       6840        113        0.0         0
# 766   3.94      0.0        960          0        0.0         0
# 767   3.94      0.0        960          0        0.0         0
# 768  22.52   1420.0       6840        113        0.0         0
# 785  22.52   1422.0       6840        113        0.0         0
# 803  22.52   1445.0       6840        113        0.0         0
#
#      no_of_style_change  no_of_workers  actual_productivity
# 337                   0            8.0             1.033570
# 437                   0           10.0             1.059621
# 456                   0           57.0             1.000230
# 457                   0           57.0             1.000230
# 477                   0           57.0             1.000230
# 478                   0           57.0             1.000230
# 498                   0           57.0             1.000230
# 518                   0           58.0             1.000457
# 519                   0           57.0             1.000230
# 542                   0            8.0             1.011562
# 543                   0           57.5             1.000671
# 544                   0           58.5             1.000402
# 561                   0           58.5             1.000602
# 580                   0           20.0             1.001417
# 581                   0           57.5             1.000019
# 599                   0           57.5             1.050281
# 600                   0           57.0             1.000230
# 618                   0           56.5             1.000446
# 619                   0           57.5             1.000019
# 636                   0           25.0             1.050667
# 637                   0           58.0             1.000019
# 655                   0           57.5             1.000019
# 674                   0           18.0             1.057963
# 692                   0            9.0             1.004889
# 711                   0           15.0             1.033156
# 712                   0            9.0             1.020000
# 713                   0           57.5             1.000345
# 714                   0           57.0             1.000066
# 730                   0           57.0             1.100484
# 731                   0           15.0             1.096633
# 732                   0           57.5             1.000345
# 749                   0           57.0             1.000230
# 766                   0            8.0             1.120437
# 767                   0            8.0             1.108125
# 768                   0           57.0             1.000230
# 785                   0           57.0             1.000230
# 803                   0           57.0             1.000230

# %%
print(ABC.columns)
# Out:
# Index(['team', 'targeted_productivity', 'smv', 'wip', 'over_time', 'incentive',
#        'idle_time', 'idle_men', 'no_of_style_change', 'no_of_workers',
#        'actual_productivity', 'quarter_Quarter2', 'quarter_Quarter3',
#        'quarter_Quarter4', 'quarter_Quarter5', 'department_finishing',
#        'department_sewing', 'day_Saturday', 'day_Sunday', 'day_Thursday',
#        'day_Tuesday', 'day_Wednesday'],
#       dtype='object')

# %%
ABC = pd.get_dummies(ABC, columns=['quarter','department','day'], drop_first=True) #dummy encode

print(ABC.columns)
# Out:
# Index(['date', 'team', 'targeted_productivity', 'smv', 'wip', 'over_time',
#        'incentive', 'idle_time', 'idle_men', 'no_of_style_change',
#        'no_of_workers', 'actual_productivity', 'quarter_Quarter2',
#        'quarter_Quarter3', 'quarter_Quarter4', 'quarter_Quarter5',
#        'department_finishing ', 'department_sewing', 'day_Saturday',
#        'day_Sunday', 'day_Thursday', 'day_Tuesday', 'day_Wednesday'],
#       dtype='object')

# %%
ABC.columns = ABC.columns.str.strip()
print(ABC.columns)
# Out:
# Index(['date', 'team', 'targeted_productivity', 'smv', 'wip', 'over_time',
#        'incentive', 'idle_time', 'idle_men', 'no_of_style_change',
#        'no_of_workers', 'actual_productivity', 'quarter_Quarter2',
#        'quarter_Quarter3', 'quarter_Quarter4', 'quarter_Quarter5',
#        'department_finishing', 'department_sewing', 'day_Saturday',
#        'day_Sunday', 'day_Thursday', 'day_Tuesday', 'day_Wednesday'],
#       dtype='object')

# %%
ABC = ABC.drop(columns=['date']) #delete unnecessary variable

# %%
print (ABC.columns)
# Out:
# Index(['team', 'targeted_productivity', 'smv', 'wip', 'over_time', 'incentive',
#        'idle_time', 'idle_men', 'no_of_style_change', 'no_of_workers',
#        'actual_productivity', 'quarter_Quarter2', 'quarter_Quarter3',
#        'quarter_Quarter4', 'quarter_Quarter5', 'department_finishing',
#        'department_sewing', 'day_Saturday', 'day_Sunday', 'day_Thursday',
#        'day_Tuesday', 'day_Wednesday'],
#       dtype='object')

# %%
print(ABC.shape)
print(ABC.columns)
ABC.head()
# Out:
# (1197, 22)
# Index(['team', 'targeted_productivity', 'smv', 'wip', 'over_time', 'incentive',
#        'idle_time', 'idle_men', 'no_of_style_change', 'no_of_workers',
#        'actual_productivity', 'quarter_Quarter2', 'quarter_Quarter3',
#        'quarter_Quarter4', 'quarter_Quarter5', 'department_finishing',
#        'department_sewing', 'day_Saturday', 'day_Sunday', 'day_Thursday',
#        'day_Tuesday', 'day_Wednesday'],
#       dtype='object')
#    team  targeted_productivity    smv     wip  over_time  incentive  \
# 0     8                   0.80  26.16  1108.0       7080         98
# 1     1                   0.75   3.94     0.0        960          0
# 2    11                   0.80  11.41   968.0       3660         50
# 3    12                   0.80  11.41   968.0       3660         50
# 4     6                   0.80  25.90  1170.0       1920         50
#
#    idle_time  idle_men  no_of_style_change  no_of_workers  ...  \
# 0        0.0         0                   0           59.0  ...
# 1        0.0         0                   0            8.0  ...
# 2        0.0         0                   0           30.5  ...
# 3        0.0         0                   0           30.5  ...
# 4        0.0         0                   0           56.0  ...
#
#    quarter_Quarter3  quarter_Quarter4  quarter_Quarter5  department_finishing  \
# 0             False             False             False                 False
# 1             False             False             False                  True
# 2             False             False             False                 False
# 3             False             False             False                 False
# 4             False             False             False                 False
#
#    department_sewing  day_Saturday  day_Sunday  day_Thursday  day_Tuesday  \
# 0               True         False       False          True        False
# 1              False         False       False          True        False
# 2               True         False       False          True        False
# 3               True         False       False          True        False
# 4               True         False       False          True        False
#
#    day_Wednesday
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#
# [5 rows x 22 columns]

# %%
#6.0 Model requirement 
#Regression analysis
X_ABC = ABC.drop('actual_productivity', axis=1)
y_ABC = ABC['actual_productivity']

print(X_ABC.shape) #confirm x and y is separate 
print(y_ABC.shape)
print(X_ABC.columns)
# Out:
# (1197, 21)
# (1197,)
# Index(['team', 'targeted_productivity', 'smv', 'wip', 'over_time', 'incentive',
#        'idle_time', 'idle_men', 'no_of_style_change', 'no_of_workers',
#        'quarter_Quarter2', 'quarter_Quarter3', 'quarter_Quarter4',
#        'quarter_Quarter5', 'department_finishing', 'department_sewing',
#        'day_Saturday', 'day_Sunday', 'day_Thursday', 'day_Tuesday',
#        'day_Wednesday'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

Xtrain, Xtest, ytrain, ytest = train_test_split(X_ABC, y_ABC,test_size=0.2, random_state=42)

print(Xtrain.shape) #957 training
print(Xtest.shape) #240 testing
# Out:
# (957, 21)
# (240, 21)

# %%
#baseline (dummyregressor)
from sklearn.dummy import DummyRegressor

baseline = DummyRegressor(strategy="mean") #Build baseline mode (predict mean)

baseline.fit(Xtrain, ytrain) #Training through y and x

y_pred_base = baseline.predict(Xtest) #use data(test) predict

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import numpy as np

mae = mean_absolute_error(ytest, y_pred_base)
rmse = np.sqrt(mean_squared_error(ytest, y_pred_base))
r2 = r2_score(ytest, y_pred_base)

print("Baseline Results:")
print("MAE:", round(mae,4))
print("RMSE:", round(rmse,4))
print("R2:", round(r2,4))
# Out:
# Baseline Results:
# MAE: 0.1274
# RMSE: 0.1635
# R2: -0.0064

# %%
#2. model (Linear Regression)
from sklearn.linear_model import LinearRegression

linreg = LinearRegression() # Build model
linreg.fit(Xtrain, ytrain) # Train
y_pred_lin = linreg.predict(Xtest) # Predict and from 1197 record find related average 

# Evaluate (sklearn Scoring formula)
mae = mean_absolute_error(ytest, y_pred_lin)
rmse = np.sqrt(mean_squared_error(ytest, y_pred_lin))
r2 = r2_score(ytest, y_pred_lin)

print("Linear Regression Results:")
print("MAE:", round(mae,4))
print("RMSE:", round(rmse,4))
print("R2:", round(r2,4))
# Out:
# Linear Regression Results:
# MAE: 0.1085
# RMSE: 0.1486
# R2: 0.1682

# %%
#3. Ridge Regression
from sklearn.linear_model import Ridge

ridge = Ridge(alpha=1.0) #punish
ridge.fit(Xtrain, ytrain)
y_pred_ridge = ridge.predict(Xtest)

mae = mean_absolute_error(ytest, y_pred_ridge)
rmse = np.sqrt(mean_squared_error(ytest, y_pred_ridge))
r2 = r2_score(ytest, y_pred_ridge)

print("Ridge Regression Results:")
print("MAE:", round(mae,4))
print("RMSE:", round(rmse,4))
print("R2:", round(r2,4))
# Out:
# Ridge Regression Results:
# MAE: 0.1092
# RMSE: 0.1487
# R2: 0.1668

# %%
#4. model (Random Forest Regressor)
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=100, random_state=42) #use 100 test from 42
rf.fit(Xtrain, ytrain) #Train
y_pred_rf = rf.predict(Xtest)

mae = mean_absolute_error(ytest, y_pred_rf)
rmse = np.sqrt(mean_squared_error(ytest, y_pred_rf))
r2 = r2_score(ytest, y_pred_rf)

print("Random Forest Results:")
print("MAE:", round(mae,4))
print("RMSE:", round(rmse,4))
print("R2:", round(r2,4))
# Out:
# Random Forest Results:
# MAE: 0.0729
# RMSE: 0.1181
# R2: 0.4748

# %%
#parameter tuning
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge

param = {'alpha': [0.01, 0.1, 1, 10, 100]}

ridge = Ridge()
grid_ridge = GridSearchCV(ridge, param, cv=5, scoring='r2')
grid_ridge.fit(Xtrain, ytrain)

print("Best Parameter:", grid_ridge.best_params_)
print("Best Estimator:", grid_ridge.best_estimator_)
print("Best CV R2:", grid_ridge.best_score_)
# Out:
# Best Parameter: {'alpha': 0.1}
# Best Estimator: Ridge(alpha=0.1)
# Best CV R2: 0.1963550131048952

# %%
import joblib

joblib.dump(linreg, "lin_model.joblib")
joblib.dump(ridge, "ridge_model.joblib")
joblib.dump(rf, "rf_model.joblib")

#save feature columsn sequence 
joblib.dump(list(Xtrain.columns), "feature_columns.joblib")
print("Saved models + feature columns!")
# Out:
# Saved models + feature columns!

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\acer\\anaconda_projects\\22fe23f7-1b4d-436d-861d-ccf978e00d6e'
